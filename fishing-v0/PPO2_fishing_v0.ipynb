# %% [markdown]
# <a href="https://colab.research.google.com/github/NC25/gym_fishing/blob/master/fishing-v0/PPO2_fishing_v0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Dependencies

# %%
# %tensorflow_version 1.x
# !apt-get install ffmpeg freeglut3-dev xvfb  # For visualization
# !pip install stable-baselines[mpi]==2.10.0

# %% [markdown]
# # Packaging

# %%
# !git clone https://github.com/boettiger-lab/gym_fishing.git

# %%
# !python gym_fishing/setup.py sdist bdist_wheel

# %%
# !pip install -e ./gym_fishing/

# %%
# !ls

# %%
# !cd gym_fishing

# %%
import gym_fishing

# %% [markdown]
# # Remove Warnings

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # or any {'0', '1', '2'}
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)
import tensorflow as tf
tf.get_logger().setLevel('INFO')
tf.autograph.set_verbosity(0)
import logging
tf.get_logger().setLevel(logging.ERROR)

# %% [markdown]
# # Imports

# %%
import pandas as pd

# %%
import gym

# %%
import numpy as np

# %%
from stable_baselines import PPO2

from stable_baselines.common.policies import MlpPolicy

# %%
env = gym.make('fishing-v0')
model = PPO2(MlpPolicy, env , verbose=2)
# Out:
# Wrapping the env in a DummyVecEnv.

# %%
obs = env.reset()
for i in range(100):
  action, _states = model.predict(obs)
  obs, rewards, dones, info = env.step(action)
  print("harvest: " + str(action) + "\n" + "obs: " + str(obs) + "\n" + str(rewards) + "\n" + str(dones) + "\n" + str(info))
  env.render()
  
env.close()
# Out:
# harvest: 2
# obs: [0.74394534]
# 0.010000000000000002
# False
# {}
# harvest: 1
# obs: [0.74460623]
# 0.012000000000000002
# False
# {}
# harvest: 1
# obs: [0.74283492]
# 0.014400000000000001
# False
# {}
# harvest: 1
# obs: [0.74797786]
# 0.01728
# False
# {}
# harvest: 1
# obs: [0.7535071]
# 0.020736
# False
# {}
# harvest: 0
# obs: [0.74216733]
# 0.020736
# False
# {}
# harvest: 1
# obs: [0.74917526]
# 0.0248832
# False
# {}
# harvest: 1
# obs: [0.73973179]
# 0.02985984
# False
# {}
# harvest: 0
# obs: [0.72438768]
# 0.02985984
# False
# {}
# harvest: 0
# obs: [0.71583256]
# 0.02985984
# False
# {}
# harvest: 2
# obs: [0.72745732]
# 0.023887872
# False
# {}
# harvest: 2
# obs: [0.73938066]
# 0.019110297600000003
# False
# {}
# harvest: 1
# obs: [0.73946722]
# 0.022932357120000003
# False
# {}
# harvest: 1
# obs: [0.73208245]
# 0.027518828544000003
# False
# {}
# harvest: 2
# obs: [0.73845657]
# 0.022015062835200005
# False
# {}
# harvest: 0
# obs: [0.7504917]
# 0.022015062835200005
# False
# {}
# harvest: 0
# obs: [0.74896835]
# 0.022015062835200005
# False
# {}
# harvest: 2
# obs: [0.75895795]
# 0.017612050268160005
# False
# {}
# harvest: 1
# obs: [0.7414027]
# 0.021134460321792007
# False
# {}
# harvest: 2
# obs: [0.74556576]
# 0.016907568257433607
# False
# {}
# harvest: 2
# obs: [0.74934923]
# 0.013526054605946886
# False
# {}
# harvest: 0
# obs: [0.75221605]
# 0.013526054605946886
# False
# {}
# harvest: 2
# obs: [0.76724839]
# 0.01082084368475751
# False
# {}
# harvest: 2
# obs: [0.76752693]
# 0.008656674947806009
# False
# {}
# harvest: 1
# obs: [0.76872507]
# 0.01038800993736721
# False
# {}
# harvest: 2
# obs: [0.78816261]
# 0.008310407949893768
# False
# {}
# harvest: 1
# obs: [0.78431005]
# 0.009972489539872521
# False
# {}
# harvest: 1
# obs: [0.79082762]
# 0.011966987447847025
# False
# {}
# harvest: 0
# obs: [0.80348238]
# 0.011966987447847025
# False
# {}
# harvest: 0
# obs: [0.80160813]
# 0.011966987447847025
# False
# {}
# harvest: 0
# obs: [0.81149274]
# 0.011966987447847025
# False
# {}
# harvest: 0
# obs: [0.79746704]
# 0.011966987447847025
# False
# {}
# harvest: 1
# obs: [0.80501185]
# 0.01436038493741643
# False
# {}
# harvest: 1
# obs: [0.80176595]
# 0.017232461924899713
# False
# {}
# harvest: 2
# obs: [0.80332304]
# 0.01378596953991977
# False
# {}
# harvest: 1
# obs: [0.80787763]
# 0.016543163447903724
# False
# {}
# harvest: 2
# obs: [0.81694465]
# 0.01323453075832298
# False
# {}
# harvest: 1
# obs: [0.81402189]
# 0.015881436909987577
# False
# {}
# harvest: 1
# obs: [0.82002492]
# 0.01905772429198509
# False
# {}
# harvest: 2
# obs: [0.81722616]
# 0.015246179433588074
# False
# {}
# harvest: 2
# obs: [0.83398681]
# 0.01219694354687046
# False
# {}
# harvest: 2
# obs: [0.83815921]
# 0.009757554837496369
# False
# {}
# harvest: 2
# obs: [0.83865119]
# 0.0078060438699970956
# False
# {}
# harvest: 1
# obs: [0.84460646]
# 0.009367252643996514
# False
# {}
# harvest: 0
# obs: [0.84142412]
# 0.009367252643996514
# False
# {}
# harvest: 2
# obs: [0.85415593]
# 0.007493802115197211
# False
# {}
# harvest: 1
# obs: [0.86501857]
# 0.008992562538236652
# False
# {}
# harvest: 0
# obs: [0.86475871]
# 0.008992562538236652
# False
# {}
# harvest: 1
# obs: [0.85756148]
# 0.010791075045883983
# False
# {}
# harvest: 2
# obs: [0.86784111]
# 0.008632860036707187
# False
# {}
# harvest: 1
# obs: [0.89057703]
# 0.010359432044048624
# False
# {}
# harvest: 2
# obs: [0.89132593]
# 0.0082875456352389
# False
# {}
# harvest: 1
# obs: [0.88687815]
# 0.00994505476228668
# False
# {}
# harvest: 0
# obs: [0.87967224]
# 0.00994505476228668
# False
# {}
# harvest: 0
# obs: [0.88027568]
# 0.00994505476228668
# False
# {}
# harvest: 1
# obs: [0.87946504]
# 0.011934065714744016
# False
# {}
# harvest: 2
# obs: [0.87832129]
# 0.009547252571795214
# False
# {}
# harvest: 0
# obs: [0.87546111]
# 0.009547252571795214
# False
# {}
# harvest: 2
# obs: [0.88677524]
# 0.007637802057436172
# False
# {}
# harvest: 0
# obs: [0.88396227]
# 0.007637802057436172
# False
# {}
# harvest: 2
# obs: [0.88728573]
# 0.006110241645948938
# False
# {}
# harvest: 2
# obs: [0.8907919]
# 0.004888193316759151
# False
# {}
# harvest: 2
# obs: [0.89871575]
# 0.0039105546534073206
# False
# {}
# harvest: 2
# obs: [0.91245461]
# 0.0031284437227258564
# False
# {}
# harvest: 0
# obs: [0.91310705]
# 0.0031284437227258564
# False
# {}
# harvest: 0
# obs: [0.9029492]
# 0.0031284437227258564
# False
# {}
# harvest: 2
# obs: [0.90291629]
# 0.002502754978180685
# False
# {}
# harvest: 1
# obs: [0.90737072]
# 0.0030033059738168223
# False
# {}
# harvest: 2
# obs: [0.9009245]
# 0.002402644779053458
# False
# {}
# harvest: 2
# obs: [0.91206237]
# 0.0019221158232427663
# False
# {}
# harvest: 0
# obs: [0.93102633]
# 0.0019221158232427663
# False
# {}
# harvest: 0
# obs: [0.93317708]
# 0.0019221158232427663
# False
# {}
# harvest: 1
# obs: [0.953953]
# 0.0023065389878913194
# False
# {}
# harvest: 1
# obs: [0.95199822]
# 0.002767846785469583
# False
# {}
# harvest: 2
# obs: [0.95750013]
# 0.0022142774283756667
# False
# {}
# harvest: 1
# obs: [0.95649179]
# 0.0026571329140508
# False
# {}
# harvest: 2
# obs: [0.95485082]
# 0.00212570633124064
# False
# {}
# harvest: 0
# obs: [0.96726343]
# 0.00212570633124064
# False
# {}
# harvest: 2
# obs: [0.96960967]
# 0.0017005650649925123
# False
# {}
# harvest: 0
# obs: [0.97910386]
# 0.0017005650649925123
# False
# {}
# harvest: 0
# obs: [0.97599453]
# 0.0017005650649925123
# False
# {}
# harvest: 2
# obs: [0.9930424]
# 0.0013604520519940099
# False
# {}
# harvest: 1
# obs: [0.99052225]
# 0.0016325424623928118
# False
# {}
# harvest: 1
# obs: [0.9934986]
# 0.001959050954871374
# False
# {}
# harvest: 2
# obs: [0.99283897]
# 0.0015672407638970993
# False
# {}
# harvest: 1
# obs: [0.98319515]
# 0.0018806889166765191
# False
# {}
# harvest: 0
# obs: [0.98135488]
# 0.0018806889166765191
# False
# {}
# harvest: 2
# obs: [0.96916046]
# 0.0015045511333412155
# False
# {}
# harvest: 2
# obs: [0.9619084]
# 0.0012036409066729726
# False
# {}
# harvest: 1
# obs: [0.95743342]
# 0.001444369088007567
# False
# {}
# harvest: 2
# obs: [0.97533173]
# 0.0011554952704060535
# False
# {}
# harvest: 0
# obs: [0.96666164]
# 0.0011554952704060535
# False
# {}
# harvest: 2
# obs: [0.95636001]
# 0.0009243962163248429
# False
# {}
# harvest: 2
# obs: [0.95826472]
# 0.0007395169730598744
# False
# {}
# harvest: 1
# obs: [0.96274117]
# 0.0008874203676718492
# False
# {}
# harvest: 0
# obs: [0.96168763]
# 0.0008874203676718492
# False
# {}
# harvest: 2
# obs: [0.96354347]
# 0.0007099362941374794
# False
# {}
# harvest: 0
# obs: [0.96220902]
# 0.0007099362941374794
# False
# {}
# harvest: 2
# obs: [0.94768416]
# 0.0005679490353099836
# False
# {}
# harvest: 1
# obs: [0.95191434]
# 0.0006815388423719802
# False
# {}

# %%
def evaluate(model, num_episodes=100): #episodes are the # of attempts the agent has to learn the env
  #returns mean reward
  env = model.get_env()
  all_episode_rewards = []
  total_action_space = []
  for episode in range(num_episodes):
    episode_rewards = []
    action_space = []
    done = False
    obs = env.reset()
    while not done:
      action, _states = model.predict(obs)
      obs, reward, done, info = env.step(action)
      episode_rewards.append(reward)
      action_space.append(action)
    all_episode_rewards.append(sum(episode_rewards))
    total_action_space.append(action_space)

  current_action_space = total_action_space.append(action_space)
  print("Actions taken: " + str(current_action_space))

  mean_episode_reward = np.mean(all_episode_rewards)
  print("Mean episode reward: " + str(mean_episode_reward) + " Number of episodes: " + str(num_episodes))

  return mean_episode_reward
  return current_action_space

#save helper

# %%
before_train_agent = evaluate(model)

# %%
#from stable_baselines3.common.evaluation import evaluate_policy 1.679

# %%
 trained_model = model.learn(total_timesteps=10000)
# Out:
# --------------------------------------
# | approxkl           | 0.00013798967 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.098         |
# | fps                | 230           |
# | n_updates          | 1             |
# | policy_entropy     | 1.0984386     |
# | policy_loss        | -0.0028428696 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 3.19e-05      |
# | total_timesteps    | 128           |
# | value_loss         | 0.048134048   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00017571829 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0142       |
# | fps                | 935           |
# | n_updates          | 2             |
# | policy_entropy     | 1.0971485     |
# | policy_loss        | -0.0014365921 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 0.556         |
# | total_timesteps    | 256           |
# | value_loss         | 0.0016803794  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00026540304 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.296        |
# | fps                | 934           |
# | n_updates          | 3             |
# | policy_entropy     | 1.0941948     |
# | policy_loss        | -0.002125888  |
# | serial_timesteps   | 384           |
# | time_elapsed       | 0.694         |
# | total_timesteps    | 384           |
# | value_loss         | 0.0002778912  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0002557535   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.251         |
# | fps                | 932            |
# | n_updates          | 4              |
# | policy_entropy     | 1.088977       |
# | policy_loss        | -0.00076958584 |
# | serial_timesteps   | 512            |
# | time_elapsed       | 0.832          |
# | total_timesteps    | 512            |
# | value_loss         | 5.5827786e-05  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00036436948 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0319       |
# | fps                | 971           |
# | n_updates          | 5             |
# | policy_entropy     | 1.084947      |
# | policy_loss        | -0.0033436425 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 0.97          |
# | total_timesteps    | 640           |
# | value_loss         | 0.02355603    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0009832934 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.23        |
# | fps                | 1050         |
# | n_updates          | 6            |
# | policy_entropy     | 1.0704943    |
# | policy_loss        | -0.005051325 |
# | serial_timesteps   | 768          |
# | time_elapsed       | 1.1          |
# | total_timesteps    | 768          |
# | value_loss         | 0.0054176683 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0004497014  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.271        |
# | fps                | 1033          |
# | n_updates          | 7             |
# | policy_entropy     | 1.0568993     |
# | policy_loss        | -0.0013624423 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 1.23          |
# | total_timesteps    | 896           |
# | value_loss         | 0.0030230556  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015542132 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.647         |
# | fps                | 944           |
# | n_updates          | 8             |
# | policy_entropy     | 1.0676644     |
# | policy_loss        | -0.0009803227 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 1.35          |
# | total_timesteps    | 1024          |
# | value_loss         | 0.015735716   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.413004e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.718         |
# | fps                | 1031          |
# | n_updates          | 9             |
# | policy_entropy     | 1.0622904     |
# | policy_loss        | 5.5483077e-05 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 1.49          |
# | total_timesteps    | 1152          |
# | value_loss         | 0.010420263   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.0891427e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.834         |
# | fps                | 894           |
# | n_updates          | 10            |
# | policy_entropy     | 1.0643213     |
# | policy_loss        | -0.0011714791 |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 1.61          |
# | total_timesteps    | 1280          |
# | value_loss         | 0.009599132   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.728063e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.83          |
# | fps                | 988           |
# | n_updates          | 11            |
# | policy_entropy     | 1.0545361     |
# | policy_loss        | 0.00028800062 |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 1.76          |
# | total_timesteps    | 1408          |
# | value_loss         | 0.011015435   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020851684 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.682         |
# | fps                | 1045          |
# | n_updates          | 12            |
# | policy_entropy     | 1.0655783     |
# | policy_loss        | -0.0031566215 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 1.89          |
# | total_timesteps    | 1536          |
# | value_loss         | 0.015353854   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00022617249 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.853         |
# | fps                | 962           |
# | n_updates          | 13            |
# | policy_entropy     | 1.0633444     |
# | policy_loss        | -0.0005139993 |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 2.01          |
# | total_timesteps    | 1664          |
# | value_loss         | 0.010971448   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 6.1708226e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.903          |
# | fps                | 975            |
# | n_updates          | 14             |
# | policy_entropy     | 1.0649894      |
# | policy_loss        | -0.00019305281 |
# | serial_timesteps   | 1792           |
# | time_elapsed       | 2.14           |
# | total_timesteps    | 1792           |
# | value_loss         | 0.008528965    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00044701868 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.878         |
# | fps                | 1020          |
# | n_updates          | 15            |
# | policy_entropy     | 1.0612462     |
# | policy_loss        | -0.005680208  |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 2.28          |
# | total_timesteps    | 1920          |
# | value_loss         | 0.008683147   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024326399 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.395        |
# | fps                | 916           |
# | n_updates          | 16            |
# | policy_entropy     | 1.067569      |
# | policy_loss        | 0.0017698191  |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 2.4           |
# | total_timesteps    | 2048          |
# | value_loss         | 0.0027959852  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011159041 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.727        |
# | fps                | 973           |
# | n_updates          | 17            |
# | policy_entropy     | 1.0697882     |
# | policy_loss        | -0.0005918257 |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 2.54          |
# | total_timesteps    | 2176          |
# | value_loss         | 0.0013911359  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 6.659115e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.905          |
# | fps                | 889            |
# | n_updates          | 18             |
# | policy_entropy     | 1.0805069      |
# | policy_loss        | -0.00066433335 |
# | serial_timesteps   | 2304           |
# | time_elapsed       | 2.68           |
# | total_timesteps    | 2304           |
# | value_loss         | 0.0055001797   |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.000106964115 |
# | clipfrac           | 0.0            |
# | explained_variance | 0.894          |
# | fps                | 1014           |
# | n_updates          | 19             |
# | policy_entropy     | 1.0813923      |
# | policy_loss        | -0.0011396017  |
# | serial_timesteps   | 2432           |
# | time_elapsed       | 2.82           |
# | total_timesteps    | 2432           |
# | value_loss         | 0.0055465717   |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.0135682e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.904          |
# | fps                | 994            |
# | n_updates          | 20             |
# | policy_entropy     | 1.0915095      |
# | policy_loss        | 0.000104097184 |
# | serial_timesteps   | 2560           |
# | time_elapsed       | 2.95           |
# | total_timesteps    | 2560           |
# | value_loss         | 0.0076861847   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 6.0647755e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.311         |
# | fps                | 966           |
# | n_updates          | 21            |
# | policy_entropy     | 1.0863672     |
# | policy_loss        | -0.0008684145 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 3.08          |
# | total_timesteps    | 2688          |
# | value_loss         | 0.009365791   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.438592e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.919          |
# | fps                | 976            |
# | n_updates          | 22             |
# | policy_entropy     | 1.090847       |
# | policy_loss        | -0.00032577605 |
# | serial_timesteps   | 2816           |
# | time_elapsed       | 3.21           |
# | total_timesteps    | 2816           |
# | value_loss         | 0.006317763    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.6256532e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.936         |
# | fps                | 933           |
# | n_updates          | 23            |
# | policy_entropy     | 1.0878272     |
# | policy_loss        | 9.826827e-05  |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 3.34          |
# | total_timesteps    | 2944          |
# | value_loss         | 0.0085291555  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.6310016e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -3.32         |
# | fps                | 945           |
# | n_updates          | 24            |
# | policy_entropy     | 1.086628      |
# | policy_loss        | 1.8336577e-06 |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 3.48          |
# | total_timesteps    | 3072          |
# | value_loss         | 0.004871017   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000111357964 |
# | clipfrac           | 0.0            |
# | explained_variance | 0.944          |
# | fps                | 869            |
# | n_updates          | 25             |
# | policy_entropy     | 1.087207       |
# | policy_loss        | -0.0014255436  |
# | serial_timesteps   | 3200           |
# | time_elapsed       | 3.62           |
# | total_timesteps    | 3200           |
# | value_loss         | 0.0047933403   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00023938375 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.405        |
# | fps                | 978           |
# | n_updates          | 26            |
# | policy_entropy     | 1.0749949     |
# | policy_loss        | -0.0010771417 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 3.77          |
# | total_timesteps    | 3328          |
# | value_loss         | 0.0049613537  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0004220485 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.913        |
# | fps                | 851          |
# | n_updates          | 27           |
# | policy_entropy     | 1.0751855    |
# | policy_loss        | -0.003877234 |
# | serial_timesteps   | 3456         |
# | time_elapsed       | 3.9          |
# | total_timesteps    | 3456         |
# | value_loss         | 0.003903392  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 1.617031e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.879         |
# | fps                | 982           |
# | n_updates          | 28            |
# | policy_entropy     | 1.0708036     |
# | policy_loss        | 0.00017493672 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 4.05          |
# | total_timesteps    | 3584          |
# | value_loss         | 0.0039444864  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024083356 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.952         |
# | fps                | 983           |
# | n_updates          | 29            |
# | policy_entropy     | 1.0735369     |
# | policy_loss        | -0.002022005  |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 4.18          |
# | total_timesteps    | 3712          |
# | value_loss         | 0.0022983516  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0001098271   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.888          |
# | fps                | 929            |
# | n_updates          | 30             |
# | policy_entropy     | 1.0760949      |
# | policy_loss        | -0.00033707963 |
# | serial_timesteps   | 3840           |
# | time_elapsed       | 4.31           |
# | total_timesteps    | 3840           |
# | value_loss         | 0.0066723255   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 8.9230554e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.905         |
# | fps                | 919           |
# | n_updates          | 31            |
# | policy_entropy     | 1.0764129     |
# | policy_loss        | -0.0008180839 |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 4.45          |
# | total_timesteps    | 3968          |
# | value_loss         | 0.004454221   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00021279049 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.953         |
# | fps                | 745           |
# | n_updates          | 32            |
# | policy_entropy     | 1.0857342     |
# | policy_loss        | -0.0017950216 |
# | serial_timesteps   | 4096          |
# | time_elapsed       | 4.59          |
# | total_timesteps    | 4096          |
# | value_loss         | 0.004220661   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020667532 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.902         |
# | fps                | 924           |
# | n_updates          | 33            |
# | policy_entropy     | 1.0877931     |
# | policy_loss        | -0.0023337195 |
# | serial_timesteps   | 4224          |
# | time_elapsed       | 4.76          |
# | total_timesteps    | 4224          |
# | value_loss         | 0.007094086   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00036276554 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0858        |
# | fps                | 979           |
# | n_updates          | 34            |
# | policy_entropy     | 1.0917147     |
# | policy_loss        | -0.004091258  |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 4.9           |
# | total_timesteps    | 4352          |
# | value_loss         | 0.0013195054  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020500174 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.913         |
# | fps                | 989           |
# | n_updates          | 35            |
# | policy_entropy     | 1.0957961     |
# | policy_loss        | -0.002506608  |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 5.03          |
# | total_timesteps    | 4480          |
# | value_loss         | 0.005438499   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.0543688e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.551         |
# | fps                | 976           |
# | n_updates          | 36            |
# | policy_entropy     | 1.0967216     |
# | policy_loss        | 0.00020212797 |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 5.16          |
# | total_timesteps    | 4608          |
# | value_loss         | 0.004564837   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.291425e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.38         |
# | fps                | 964           |
# | n_updates          | 37            |
# | policy_entropy     | 1.0958334     |
# | policy_loss        | -0.0011200521 |
# | serial_timesteps   | 4736          |
# | time_elapsed       | 5.3           |
# | total_timesteps    | 4736          |
# | value_loss         | 0.0058653075  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.5051157e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.315        |
# | fps                | 945           |
# | n_updates          | 38            |
# | policy_entropy     | 1.0943462     |
# | policy_loss        | 0.0003661671  |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 5.43          |
# | total_timesteps    | 4864          |
# | value_loss         | 0.0033907339  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.0218837e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.022         |
# | fps                | 1005           |
# | n_updates          | 39             |
# | policy_entropy     | 1.094703       |
# | policy_loss        | -1.8007937e-05 |
# | serial_timesteps   | 4992           |
# | time_elapsed       | 5.57           |
# | total_timesteps    | 4992           |
# | value_loss         | 0.002591959    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 9.244814e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.231         |
# | fps                | 947            |
# | n_updates          | 40             |
# | policy_entropy     | 1.0948482      |
# | policy_loss        | -0.00020787411 |
# | serial_timesteps   | 5120           |
# | time_elapsed       | 5.7            |
# | total_timesteps    | 5120           |
# | value_loss         | 0.0015035194   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.905215e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.761        |
# | fps                | 980           |
# | n_updates          | 41            |
# | policy_entropy     | 1.096198      |
# | policy_loss        | -0.0013587005 |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 5.83          |
# | total_timesteps    | 5248          |
# | value_loss         | 0.0010986652  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 9.173896e-06 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.111       |
# | fps                | 896          |
# | n_updates          | 42           |
# | policy_entropy     | 1.0972818    |
# | policy_loss        | 0.0002916957 |
# | serial_timesteps   | 5376         |
# | time_elapsed       | 5.96         |
# | total_timesteps    | 5376         |
# | value_loss         | 0.0007238674 |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 1.566525e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.432         |
# | fps                | 1044           |
# | n_updates          | 43             |
# | policy_entropy     | 1.0973524      |
# | policy_loss        | -0.00035628304 |
# | serial_timesteps   | 5504           |
# | time_elapsed       | 6.11           |
# | total_timesteps    | 5504           |
# | value_loss         | 0.033211656    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.5370415e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.807        |
# | fps                | 969           |
# | n_updates          | 44            |
# | policy_entropy     | 1.0961391     |
# | policy_loss        | -0.0021480033 |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 6.23          |
# | total_timesteps    | 5632          |
# | value_loss         | 0.0028933256  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.0659854e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.126         |
# | fps                | 899           |
# | n_updates          | 45            |
# | policy_entropy     | 1.0944185     |
# | policy_loss        | 0.00016947719 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 6.37          |
# | total_timesteps    | 5760          |
# | value_loss         | 0.00093243486 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.149683e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.396        |
# | fps                | 884           |
# | n_updates          | 46            |
# | policy_entropy     | 1.0958954     |
# | policy_loss        | -2.786261e-05 |
# | serial_timesteps   | 5888          |
# | time_elapsed       | 6.51          |
# | total_timesteps    | 5888          |
# | value_loss         | 0.00085745566 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.1927542e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.779        |
# | fps                | 938           |
# | n_updates          | 47            |
# | policy_entropy     | 1.096825      |
# | policy_loss        | -0.0005052546 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 6.65          |
# | total_timesteps    | 6016          |
# | value_loss         | 0.00058653613 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.721966e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.195        |
# | fps                | 973           |
# | n_updates          | 48            |
# | policy_entropy     | 1.0977714     |
# | policy_loss        | -0.0011082554 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 6.79          |
# | total_timesteps    | 6144          |
# | value_loss         | 0.00030174022 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.6809543e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.412         |
# | fps                | 1055           |
# | n_updates          | 49             |
# | policy_entropy     | 1.0981206      |
# | policy_loss        | -0.00048175012 |
# | serial_timesteps   | 6272           |
# | time_elapsed       | 6.93           |
# | total_timesteps    | 6272           |
# | value_loss         | 0.0002266676   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.3229057e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.189        |
# | fps                | 1060          |
# | n_updates          | 50            |
# | policy_entropy     | 1.097629      |
# | policy_loss        | 3.6179088e-05 |
# | serial_timesteps   | 6400          |
# | time_elapsed       | 7.05          |
# | total_timesteps    | 6400          |
# | value_loss         | 0.00016096688 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.78698e-06    |
# | clipfrac           | 0.0            |
# | explained_variance | -0.486         |
# | fps                | 996            |
# | n_updates          | 51             |
# | policy_entropy     | 1.0973333      |
# | policy_loss        | -0.00018329313 |
# | serial_timesteps   | 6528           |
# | time_elapsed       | 7.17           |
# | total_timesteps    | 6528           |
# | value_loss         | 0.0017747793   |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.2430395e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.54          |
# | fps                | 924            |
# | n_updates          | 52             |
# | policy_entropy     | 1.097099       |
# | policy_loss        | -0.00044704787 |
# | serial_timesteps   | 6656           |
# | time_elapsed       | 7.3            |
# | total_timesteps    | 6656           |
# | value_loss         | 3.7829883e-05  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.5380213e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0812        |
# | fps                | 1009          |
# | n_updates          | 53            |
# | policy_entropy     | 1.09745       |
# | policy_loss        | -0.0012723274 |
# | serial_timesteps   | 6784          |
# | time_elapsed       | 7.44          |
# | total_timesteps    | 6784          |
# | value_loss         | 5.667284e-05  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.92393e-05   |
# | clipfrac           | 0.0           |
# | explained_variance | -1.28         |
# | fps                | 1020          |
# | n_updates          | 54            |
# | policy_entropy     | 1.0970027     |
# | policy_loss        | -0.0009979658 |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 7.57          |
# | total_timesteps    | 6912          |
# | value_loss         | 3.906387e-05  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00010414519 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.235         |
# | fps                | 944           |
# | n_updates          | 55            |
# | policy_entropy     | 1.0956758     |
# | policy_loss        | -0.0014421255 |
# | serial_timesteps   | 7040          |
# | time_elapsed       | 7.69          |
# | total_timesteps    | 7040          |
# | value_loss         | 2.0687812e-05 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00010475547 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0875       |
# | fps                | 1023          |
# | n_updates          | 56            |
# | policy_entropy     | 1.094501      |
# | policy_loss        | -0.0015894556 |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 7.83          |
# | total_timesteps    | 7168          |
# | value_loss         | 1.1331936e-05 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013452824 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.539         |
# | fps                | 1070          |
# | n_updates          | 57            |
# | policy_entropy     | 1.0948111     |
# | policy_loss        | -0.002324794  |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 7.96          |
# | total_timesteps    | 7296          |
# | value_loss         | 4.873787e-06  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.9108502e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.87         |
# | fps                | 1045          |
# | n_updates          | 58            |
# | policy_entropy     | 1.0963243     |
# | policy_loss        | 0.00039223605 |
# | serial_timesteps   | 7424          |
# | time_elapsed       | 8.08          |
# | total_timesteps    | 7424          |
# | value_loss         | 7.1769996e-06 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.808693e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.14          |
# | fps                | 910            |
# | n_updates          | 59             |
# | policy_entropy     | 1.0957798      |
# | policy_loss        | -0.00062147854 |
# | serial_timesteps   | 7552           |
# | time_elapsed       | 8.2            |
# | total_timesteps    | 7552           |
# | value_loss         | 0.005050248    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 4.465688e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -1.13          |
# | fps                | 910            |
# | n_updates          | 60             |
# | policy_entropy     | 1.0939107      |
# | policy_loss        | -0.00035226997 |
# | serial_timesteps   | 7680           |
# | time_elapsed       | 8.34           |
# | total_timesteps    | 7680           |
# | value_loss         | 4.0175608e-05  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.4247573e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.133         |
# | fps                | 1018          |
# | n_updates          | 61            |
# | policy_entropy     | 1.0931189     |
# | policy_loss        | -2.241414e-05 |
# | serial_timesteps   | 7808          |
# | time_elapsed       | 8.48          |
# | total_timesteps    | 7808          |
# | value_loss         | 3.3820867e-05 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.1025568e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -3.2          |
# | fps                | 909           |
# | n_updates          | 62            |
# | policy_entropy     | 1.0927359     |
# | policy_loss        | 3.9192848e-05 |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 8.61          |
# | total_timesteps    | 7936          |
# | value_loss         | 8.067759e-06  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.8767826e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.105         |
# | fps                | 868            |
# | n_updates          | 63             |
# | policy_entropy     | 1.0919439      |
# | policy_loss        | -0.00093337847 |
# | serial_timesteps   | 8064           |
# | time_elapsed       | 8.75           |
# | total_timesteps    | 8064           |
# | value_loss         | 1.8794952e-05  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0003260283  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0601       |
# | fps                | 1078          |
# | n_updates          | 64            |
# | policy_entropy     | 1.0874819     |
# | policy_loss        | -0.001957254  |
# | serial_timesteps   | 8192          |
# | time_elapsed       | 8.9           |
# | total_timesteps    | 8192          |
# | value_loss         | 1.2813243e-05 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0006894556  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.344        |
# | fps                | 1026          |
# | n_updates          | 65            |
# | policy_entropy     | 1.0776738     |
# | policy_loss        | -0.0049858917 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 9.02          |
# | total_timesteps    | 8320          |
# | value_loss         | 8.621146e-06  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0012807511  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0223       |
# | fps                | 995           |
# | n_updates          | 66            |
# | policy_entropy     | 1.0676467     |
# | policy_loss        | -0.0069524525 |
# | serial_timesteps   | 8448          |
# | time_elapsed       | 9.15          |
# | total_timesteps    | 8448          |
# | value_loss         | 0.029901722   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00054716156 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.527         |
# | fps                | 1046          |
# | n_updates          | 67            |
# | policy_entropy     | 1.0575196     |
# | policy_loss        | -0.0010537087 |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 9.28          |
# | total_timesteps    | 8576          |
# | value_loss         | 0.022133552   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00026378728 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.802         |
# | fps                | 1031          |
# | n_updates          | 68            |
# | policy_entropy     | 1.0517882     |
# | policy_loss        | -0.0010123311 |
# | serial_timesteps   | 8704          |
# | time_elapsed       | 9.4           |
# | total_timesteps    | 8704          |
# | value_loss         | 0.008551139   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.311166e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.784          |
# | fps                | 995            |
# | n_updates          | 69             |
# | policy_entropy     | 1.0409788      |
# | policy_loss        | -0.00013062416 |
# | serial_timesteps   | 8832           |
# | time_elapsed       | 9.52           |
# | total_timesteps    | 8832           |
# | value_loss         | 0.009504739    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00028647314 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.894         |
# | fps                | 1016          |
# | n_updates          | 70            |
# | policy_entropy     | 1.0513443     |
# | policy_loss        | -0.0025780026 |
# | serial_timesteps   | 8960          |
# | time_elapsed       | 9.65          |
# | total_timesteps    | 8960          |
# | value_loss         | 0.008962809   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0007285359 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.903        |
# | fps                | 914          |
# | n_updates          | 71           |
# | policy_entropy     | 1.0580026    |
# | policy_loss        | -0.003956086 |
# | serial_timesteps   | 9088         |
# | time_elapsed       | 9.78         |
# | total_timesteps    | 9088         |
# | value_loss         | 0.0044283783 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0005218089  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.915         |
# | fps                | 967           |
# | n_updates          | 72            |
# | policy_entropy     | 1.0700682     |
# | policy_loss        | -0.0013251076 |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 9.92          |
# | total_timesteps    | 9216          |
# | value_loss         | 0.002635224   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014492808 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.854         |
# | fps                | 1006          |
# | n_updates          | 73            |
# | policy_entropy     | 1.0830783     |
# | policy_loss        | -0.0012597105 |
# | serial_timesteps   | 9344          |
# | time_elapsed       | 10.1          |
# | total_timesteps    | 9344          |
# | value_loss         | 0.006023565   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.585024e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.231         |
# | fps                | 916            |
# | n_updates          | 74             |
# | policy_entropy     | 1.0874567      |
# | policy_loss        | -0.00020908634 |
# | serial_timesteps   | 9472           |
# | time_elapsed       | 10.2           |
# | total_timesteps    | 9472           |
# | value_loss         | 0.009004169    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00015821897 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.922         |
# | fps                | 848           |
# | n_updates          | 75            |
# | policy_entropy     | 1.0881118     |
# | policy_loss        | -0.0021755141 |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 10.3          |
# | total_timesteps    | 9600          |
# | value_loss         | 0.0027527153  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015364474 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.931         |
# | fps                | 1016          |
# | n_updates          | 76            |
# | policy_entropy     | 1.0915682     |
# | policy_loss        | -0.0010383152 |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 10.5          |
# | total_timesteps    | 9728          |
# | value_loss         | 0.006733819   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.1819535e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.955          |
# | fps                | 983            |
# | n_updates          | 77             |
# | policy_entropy     | 1.0950478      |
# | policy_loss        | -0.00010143907 |
# | serial_timesteps   | 9856           |
# | time_elapsed       | 10.6           |
# | total_timesteps    | 9856           |
# | value_loss         | 0.0046982476   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 8.0044374e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.5           |
# | fps                | 885           |
# | n_updates          | 78            |
# | policy_entropy     | 1.0939411     |
# | policy_loss        | -0.0017068473 |
# | serial_timesteps   | 9984          |
# | time_elapsed       | 10.7          |
# | total_timesteps    | 9984          |
# | value_loss         | 0.0010759888  |
# --------------------------------------

# %%
evaluate(trained_model, num_episodes=100)
# Out:
# Actions taken: None
# Mean episode reward: 3.325334 Number of episodes: 100
# 3.325334

# %%
for i in range(100): #timesteps are the number of iterations the agent goes through
  action, _state = trained_model.predict(obs)
  obs, rewards, dones, info = env.step(action)
  print(action)
  print(evaluate(trained_model, num_episodes=100))
  env.render()

env.close()

# %% [markdown]
# # Saving and Loading

# %%
import os

# save directory
save_dir = '/tmp/gym/'
#creates recursive directory: fills out any missing directories
os.makedirs(save_dir, exist_ok=True) #error is not raised if target directory already exists

trained_model.save(save_dir +'PPO2_fishing-v0')     #save model

#sample observation and action
obs = trained_model.env.observation_space.sample()
action = trained_model.env.action_space.sample()

print("action + state: " + str(trained_model.predict(obs, deterministic=False)))
# Out:
# action + state: (0, None)

# %%
#del model

#load model 
loaded_model = PPO2.load(save_dir + 'PPO2_fishing')
print(loaded_model.predict(obs, deterministic=False))
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# (0, None)

# %% [markdown]
# # Loading and Tuning Previous Models
#
# Let's load a DQN

# %%
from stable_baselines import DQN
from stable_baselines import A2C

# %%
from stable_baselines.common.vec_env import DummyVecEnv

# %%
save_dir = '/tmp/gym/'
os.makedirs(save_dir, exist_ok=True)

model = A2C('MlpPolicy', 'fishing-v0', verbose=2, gamma=.9).learn(2000)
model.save(save_dir + '/DQN_fishing')

#delete model
del model
loaded_model = A2C.load(save_dir + '/DQN_fishing', verbose=2)
# Out:
# Creating environment from the given name, wrapped in a DummyVecEnv.
# ---------------------------------
# | explained_variance | 0.0154   |
# | fps                | 24       |
# | nupdates           | 1        |
# | policy_entropy     | 1.1      |
# | total_timesteps    | 5        |
# | value_loss         | 0.00167  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -0.164   |
# | fps                | 644      |
# | nupdates           | 100      |
# | policy_entropy     | 1.1      |
# | total_timesteps    | 500      |
# | value_loss         | 2.69e-05 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.07e+14 |
# | fps                | 737       |
# | nupdates           | 200       |
# | policy_entropy     | 1.1       |
# | total_timesteps    | 1000      |
# | value_loss         | 0.000214  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.384   |
# | fps                | 778      |
# | nupdates           | 300      |
# | policy_entropy     | 1.1      |
# | total_timesteps    | 1500     |
# | value_loss         | 8.57e-06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -8.81e+08 |
# | fps                | 790       |
# | nupdates           | 400       |
# | policy_entropy     | 1.1       |
# | total_timesteps    | 2000      |
# | value_loss         | 2.78e-05  |
# ----------------------------------
# Loading a model without an environment, this model cannot be trained until it has a valid environment.

# %%
#showed loaded hyperparameters
print("loaded: ", "gamma = ", loaded_model.gamma)
# Out:
# loaded:  gamma =  0.9

# %%
#Vectorize env - Allow us to train multiple envs into 1 env

loaded_model.set_env(DummyVecEnv([lambda: gym.make('fishing-v0')]))

# %% [markdown]
# # Training

# %%
loaded_model.learn(8000)
# Out:
# ---------------------------------
# | explained_variance | 0.00996  |
# | fps                | 24       |
# | nupdates           | 1        |
# | policy_entropy     | 1.1      |
# | total_timesteps    | 5        |
# | value_loss         | 0.00142  |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.195    |
# | fps                | 614      |
# | nupdates           | 100      |
# | policy_entropy     | 1.1      |
# | total_timesteps    | 500      |
# | value_loss         | 1.21e-06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -1.18e+09 |
# | fps                | 694       |
# | nupdates           | 200       |
# | policy_entropy     | 1.1       |
# | total_timesteps    | 1000      |
# | value_loss         | 9.75e-06  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.000458 |
# | fps                | 746      |
# | nupdates           | 300      |
# | policy_entropy     | 1.1      |
# | total_timesteps    | 1500     |
# | value_loss         | 0.00411  |
# ---------------------------------
# ---------------------------------
# | explained_variance | -100     |
# | fps                | 774      |
# | nupdates           | 400      |
# | policy_entropy     | 1.1      |
# | total_timesteps    | 2000     |
# | value_loss         | 0.000429 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.00103  |
# | fps                | 787      |
# | nupdates           | 500      |
# | policy_entropy     | 1.1      |
# | total_timesteps    | 2500     |
# | value_loss         | 2.72e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | -10.7    |
# | fps                | 800      |
# | nupdates           | 600      |
# | policy_entropy     | 1.1      |
# | total_timesteps    | 3000     |
# | value_loss         | 9.68e-05 |
# ---------------------------------
# ---------------------------------
# | explained_variance | 0.047    |
# | fps                | 811      |
# | nupdates           | 700      |
# | policy_entropy     | 1.1      |
# | total_timesteps    | 3500     |
# | value_loss         | 8.36e-06 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.17e+10 |
# | fps                | 818       |
# | nupdates           | 800       |
# | policy_entropy     | 1.1       |
# | total_timesteps    | 4000      |
# | value_loss         | 3.01e-07  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -4.99e+03 |
# | fps                | 825       |
# | nupdates           | 900       |
# | policy_entropy     | 1.1       |
# | total_timesteps    | 4500      |
# | value_loss         | 2.89e-08  |
# ----------------------------------
# ----------------------------------
# | explained_variance | -1.03e+06 |
# | fps                | 831       |
# | nupdates           | 1000      |
# | policy_entropy     | 1.1       |
# | total_timesteps    | 5000      |
# | value_loss         | 3.64e-07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | 0.372    |
# | fps                | 838      |
# | nupdates           | 1100     |
# | policy_entropy     | 1.1      |
# | total_timesteps    | 5500     |
# | value_loss         | 1.48e-08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -2.85e+09 |
# | fps                | 839       |
# | nupdates           | 1200      |
# | policy_entropy     | 1.1       |
# | total_timesteps    | 6000      |
# | value_loss         | 4.27e-07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -0.513   |
# | fps                | 842      |
# | nupdates           | 1300     |
# | policy_entropy     | 1.1      |
# | total_timesteps    | 6500     |
# | value_loss         | 1.25e-07 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -6.28e+04 |
# | fps                | 844       |
# | nupdates           | 1400      |
# | policy_entropy     | 1.1       |
# | total_timesteps    | 7000      |
# | value_loss         | 1.09e-07  |
# ----------------------------------
# ---------------------------------
# | explained_variance | -57.8    |
# | fps                | 846      |
# | nupdates           | 1500     |
# | policy_entropy     | 1.1      |
# | total_timesteps    | 7500     |
# | value_loss         | 2.68e-08 |
# ---------------------------------
# ----------------------------------
# | explained_variance | -7.12e+07 |
# | fps                | 850       |
# | nupdates           | 1600      |
# | policy_entropy     | 1.1       |
# | total_timesteps    | 8000      |
# | value_loss         | 4.55e-07  |
# ----------------------------------

# %% [markdown]
# # Gym and VecEnv Wrapping
#
# We can modify past environments

# %%
from stable_baselines.bench.monitor import Monitor

# %%
env = Monitor(gym.make('fishing-v0'), filename=None, allow_early_resets=True)
env = DummyVecEnv([lambda: env])

#env.get_episode_rewards()

loaded_model = DQN('MlpPolicy', env, verbose=2).learn(int(10000))
# Out:
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 100      |
# | mean 100 episode reward | 1.1      |
# | steps                   | 3376     |
# --------------------------------------
# --------------------------------------
# | % time spent exploring  | 2        |
# | episodes                | 200      |
# | mean 100 episode reward | 1.1      |
# | steps                   | 5063     |
# --------------------------------------

# %% [markdown]
# # Probability Distribution

# %%
from stable_baselines.common.distributions import MultiCategoricalProbabilityDistribution

# %%
MultiCategoricalProbabilityDistribution
